# %%
import sys
sys.path.append("../../")
from pathlib import Path
from os.path import basename, join
import time
import glob
from python.src.train import experiment_tracking_train

# %%
NUM_EPOCHS = 100  # 10
f = 0.0000001
alpha = 1
beta = 1
gamma = 0
batch_size = 1
# path = "../Data/mini"
# path = "../Data/LLL_sample_one_combination"
# path = "../Data/LLL_sample_one"
# path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/programming/generateSAT/LLL_subset"
path = join("..","..", "Data", "flat_graphs", "*")
# path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/data/BroadcastTestSet2"
# path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/data/BroadcastTestSet_subset"
# path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/programming/generateSAT/samples_LLL_n80/"
N_STEPS_MOSER = 100
N_RUNS_MOSER = 5
SEED = 0
graph_representation = "LCG"
network_type = "interaction"
# network_definition = get_network_definition(network_type = network_type, graph_representation = graph_representation) #network_definition_interaction_new

MODEL_REGISTRY = Path("../../mlrun_save")
EXPERIMENT_NAME = f"{graph_representation}_{basename(path)}_{network_type}"

timestr = time.strftime("%Y%m%d-%H%M%S")
model_path = "../params_save/" + EXPERIMENT_NAME + timestr
img_path = model_path + "_plot"
print(glob.glob(join(path, "*.cnf")))
#  AUXILIARY METHODS
# Out:
# ['../../Data/flat_graphs/SW100-8-0/sw100-23.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-37.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-36.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-22.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-34.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-20.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-21.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-35.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-31.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-25.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-19.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-18.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-24.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-30.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-26.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-32.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-33.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-27.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-83.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-97.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-68.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-4.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-40.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-54.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-55.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-41.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-5.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-69.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-96.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-82.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-94.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-80.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-7.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-57.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-43.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-42.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-56.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-6.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-81.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-95.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-91.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-85.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-52.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-46.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-2.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-3.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-47.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-53.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-84.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-90.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-86.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-92.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-45.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-51.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-79.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-1.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-78.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-50.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-44.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-93.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-87.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-49.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-61.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-75.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-74.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-60.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-48.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-100.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-89.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-76.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-62.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-63.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-77.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-88.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-98.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-73.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-67.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-66.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-72.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-99.cnf', '../../Data/flat_graphs/SW100-8-0/sw100-8.cnf', '../../Data/flat_graphs/SW100-8-0/sw1 ...

# %%
experiment_tracking_train(
        MODEL_REGISTRY,
        EXPERIMENT_NAME,
        batch_size,
        f,
        alpha,
        beta,
        gamma,
        NUM_EPOCHS,
        N_STEPS_MOSER,
        N_RUNS_MOSER,
        path,
        img_path=img_path,
        model_path=model_path,
        graph_representation=graph_representation,
        network_type=network_type,
    )
# Out:
# INFO: 'LCG__interaction' does not exist. Creating a new experiment
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 experiment_tracking_train(
#       2         MODEL_REGISTRY,
#       3         EXPERIMENT_NAME,
#       4         batch_size,
#       5         f,
#       6         alpha,
#       7         beta,
#       8         gamma,
#       9         NUM_EPOCHS,
#      10         N_STEPS_MOSER,
#      11         N_RUNS_MOSER,
#      12         path,
#      13         img_path=img_path,
#      14         model_path=model_path,
#      15         graph_representation=graph_representation,
#      16         network_type=network_type,
#      17     )
#
# File ~/Documents/Programming/moser_project/Moser/python/notebooks/../../python/src/train.py:680, in experiment_tracking_train(MODEL_REGISTRY, EXPERIMENT_NAME, batch_size, f, alpha, beta, gamma, NUM_EPOCHS, N_STEPS_MOSER, N_RUNS_MOSER, path, img_path, model_path, graph_representation, network_type)
#     663 mlflow.log_params(
#     664     {
#     665         "f": f,
#    (...)
#     677     }
#     678 )
#     679 # train and evaluate
# --> 680 artifacts = train(
#     681     batch_size,
#     682     f,
#     683     alpha,
#     684     beta,
#     685     gamma,
#     686     NUM_EPOCHS,
#     687     N_STEPS_MOSER,
#     688     N_RUNS_MOSER,
#     689     path,
#     690     img_path=img_path,
#     691     model_path=model_path,
#     692     experiment_tracking=True,
#     693     graph_representation=graph_representation,
#     694     network_type=network_type,
#     695 )
#     696 # log params which are a result of learning
#     697 with tempfile.TemporaryDirectory() as dp:
#
# File ~/Documents/Programming/moser_project/Moser/python/notebooks/../../python/src/train.py:157, in train(batch_size, f, alpha, beta, gamma, NUM_EPOCHS, N_STEPS_MOSER, N_RUNS_MOSER, path, img_path, model_path, experiment_tracking, graph_representation, network_type)
#     140 def train(
#     141     batch_size,
#     142     f,
#    (...)
#     154     network_type="interaction",
#     155 ):
#     156     if graph_representation == "LCG":
# --> 157         sat_data = SATTrainingDataset_LCG(path)
#     158         if batch_size != 1:
#     159             sys.exit(
#     160                 "Gives wrong result -> how to get correct probabilities? how to get correct energies? Need to fix this!"
#     161             )
#
# File ~/Documents/Programming/moser_project/Moser/python/notebooks/../../python/src/data_utils.py:48, in SATTrainingDataset_LCG.__init__(self, data_dir, already_unzipped, return_candidates)
#      43     instance = SATInstanceMeta(
#      44         name, cnf.nv, len(cnf.clauses), sum(len(c) for c in cnf.clauses)
#      45     )
#      46     self.instances.append(instance)
# ---> 48 self.max_n_node = max(2 * i.n + i.m for i in self.instances)
#      49 self.max_n_edge = max(i.n_edges for i in self.instances)
#
# ValueError: max() arg is an empty sequence
