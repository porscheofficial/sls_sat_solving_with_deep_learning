# %% [markdown]
# # Experiment tracking
#
# This notebook is dedicated to show how experiment tracking works with MLflow in our case. Start by loading the train function.

# %%
import sys
sys.path.append('../')

from pathlib import Path
from train_pipeline import experiment_tracking_train
from model import network_definition_GCN_single_output

# %% [markdown]
# Run an experiment:

# %%
NUM_EPOCHS = 80  # 10
f = 0.01
batch_size = 2
path = "../../Data/blocksworld"
# path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/programming/generateSAT/samples_medium/"
N_STEPS_MOSER = 1000
N_RUNS_MOSER = 2
SEED = 0
network_definition = network_definition_GCN_single_output
mode = "VCG"

MODEL_REGISTRY = Path("../../../mlrun")
EXPERIMENT_NAME = "mlflow-blocksat_interaction_LCG"
# EXPERIMENT_NAME = "mlflow-random_3SAT-medium-GCN-LCG"

experiment_tracking_train(
        MODEL_REGISTRY,
        EXPERIMENT_NAME,
        batch_size,
        f,
        NUM_EPOCHS,
        N_STEPS_MOSER,
        N_RUNS_MOSER,
        path,
        img_path="show",
        model_path=False,
        network_definition=network_definition,
        mode=mode,
    )
# Out:
# Entering training loop
# Loading problem with 1087 variables and 13772 clauses
# Round 1 ending with 344 violated clauses
# Round 2 ending with 391 violated clauses
# Loading problem with 459 variables and 7054 clauses
# Round 1 ending with 91 violated clauses
# Round 2 ending with 81 violated clauses
# Loading problem with 6325 variables and 131973 clauses
# Round 1 ending with 16863 violated clauses
# Round 2 ending with 16737 violated clauses
# 2023-02-21 15:00:45.802307: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:65] Constant folding an instruction is taking > 1s:
#
#   slice.61 (displaying the full instruction incurs a runtime overhead. Raise your logging level to 4 or above).
#
# This isn't necessarily a bug; constant-folding is inherently a trade-off between compilation time and speed at runtime.  XLA has some guards that attempt to keep constant folding from taking too long, but fundamentally you'll always be able to come up with an input program that takes a long time.
#
# If you'd like to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# 2023-02-21 15:00:45.893776: E external/org_tensorflow/tensorflow/compiler/xla/service/slow_operation_alarm.cc:133] The operation took 1.092182s
# Constant folding an instruction is taking > 1s:
#
#   slice.61 (displaying the full instruction incurs a runtime overhead. Raise your logging level to 4 or above).
#
# This isn't necessarily a bug; constant-folding is inherently a trade-off between compilation time and speed at runtime.  XLA has some guards that attempt to keep constant folding from taking too long, but fundamentally you'll always be able to come up with an input program that takes a long time.
#
# If you'd like to file a bug, run with envvar XLA_FLAGS=--xla_dump_to=/tmp/foo and attach the results.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_5/jp84zrhn28sg9yqq0sq0dkfr0000gp/T/ipykernel_67569/3066289456.py in <module>
#      14 # EXPERIMENT_NAME = "mlflow-random_3SAT-medium-GCN-LCG"
#      15
# ---> 16 experiment_tracking_train(
#      17         MODEL_REGISTRY,
#      18         EXPERIMENT_NAME,
#
# ~/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/ml_based_sat_solver/python/src/train_pipeline.py in experiment_tracking_train(MODEL_REGISTRY, EXPERIMENT_NAME, batch_size, f, NUM_EPOCHS, N_STEPS_MOSER, N_RUNS_MOSER, path, img_path, model_path, network_definition, mode)
#     400         )
#     401         # train and evaluate
# --> 402         artifacts = train(
#     403             batch_size,
#     404             f,
#
# ~/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/ml_based_sat_solver/python/src/train_pipeline.py in train(batch_size, f, NUM_EPOCHS, N_STEPS_MOSER, N_RUNS_MOSER, path, img_path, model_path, experiment_tracking, network_definition, mode)
#     312     for epoch in range(NUM_EPOCHS):
#     313         start_time = time.time()
# --> 314         for counter, batch in enumerate(train_loader):
#     315             # print("batch_number", counter)
#     316             if mode == "LCG":
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# /Applications/anaconda3/lib/python3.9/site-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     293         if isinstance(idx, list):
#     294             return self.dataset[[self.indices[i] for i in idx]]
# --> 295         return self.dataset[self.indices[idx]]
#     296
#     297     def __len__(self):
#
# ~/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/ml_based_sat_solver/python/src/data_utils.py in __getitem__(self, idx)
#     175                 pad_width=((0, 0), (0, N - n)),
#     176             )
# --> 177             energies = vmap(
#     178                 number_of_violated_constraints, in_axes=(None, 0), out_axes=0
#     179             )(problem, candidates)
#
#     [... skipping hidden 1 frame]
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in vmap_f(*args, **kwargs)
#    1680     axis_size_ = (axis_size if axis_size is not None else
#    1681                   _mapped_axis_size(fun, in_tree, args_flat, in_axes_flat, "vmap"))
# -> 1682     out_flat = batching.batch(
#    1683         flat_fun, axis_name, axis_size_, in_axes_flat,
#    1684         lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     165
#     166     try:
# --> 167       ans = self.f(*args, **dict(self.params, **kwargs))
#     168     except:
#     169       # Some transformations yield from inside context managers, so we have to
#
# ~/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/ml_based_sat_solver/python/src/random_walk.py in number_of_violated_constraints(problem, assignment)
#     102
#     103 def number_of_violated_constraints(problem: SATProblem, assignment):
# --> 104     return np.sum(violated_constraints(problem, assignment).astype(int), axis=0)
#     105
#     106
#
#     [... skipping hidden 1 frame]
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/api.py in cache_miss(*args, **kwargs)
#     624     else:
#     625       out_flat = call_bind_continuation(
# --> 626           top_trace.process_call(primitive, fun_, tracers, params))
#     627     out_pytree_def = out_tree()
#     628     out = tree_unflatten(out_pytree_def, out_flat)
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/interpreters/batching.py in process_call(self, call_primitive, f, tracers, params)
#     375     f_ = _update_annotation(f_, f.in_type, axis_size, self.axis_name, dims,
#     376                             segment_lens)
# --> 377     vals_out = call_primitive.bind(f_, *segment_lens, *vals, **params)
#     378     vals_out, dims_out = reassemble_concat_axes(vals_out, dims_out())
#     379     src = source_info_util.current()
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    2017     call_bind_continuation, top_trace, fun_, tracers, params = (
#    2018         call_bind_with_continuation(self, fun, *args, **params))
# -> 2019     outs = top_trace.process_call(self, fun_, tracers, params)
#    2020     return call_bind_continuation(outs)
#    2021
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     713
#     714   def process_call(self, primitive, f, tracers, params):
# --> 715     return primitive.impl(f, *tracers, **params)
#     716   process_map = process_call
#     717
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in _xla_call_impl(fun, device, backend, name, donated_invars, inline, keep_unused, *args)
#     240 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name,
#     241                    donated_invars, inline, keep_unused: bool):
# --> 242   compiled_fun = _xla_call_impl_lazy(
#     243       fun,
#     244       *args,
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in _xla_call_impl_lazy(***failed resolving arguments***)
#     234       raise NotImplementedError('Dynamic shapes do not work with Array.')
#     235     arg_specs = [(None, getattr(x, '_device', None)) for x in args]
# --> 236   return xla_callable(fun, device, backend, name, donated_invars, keep_unused,
#     237                       *arg_specs)
#     238
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     301       fun.populate_stores(stores)
#     302     else:
# --> 303       ans = call(fun, *args)
#     304       cache[key] = (ans, fun.stores)
#     305
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in _xla_callable_uncached(fun, device, backend, name, donated_invars, keep_unused, *arg_specs)
#     357     return computation.compile(_allow_propagation_to_outputs=True).unsafe_call
#     358   else:
# --> 359     return lower_xla_callable(fun, device, backend, name, donated_invars, False,
#     360                               keep_unused, *arg_specs).compile().unsafe_call
#     361
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in compile(self)
#     994       else:
#     995         assert self._out_type is not None
# --> 996         self._executable = XlaCompiledComputation.from_xla_computation(
#     997             self.name, self._hlo, self._in_type, self._out_type,
#     998             **self.compile_args)
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in from_xla_computation(name, xla_computation, in_type, out_type, nreps, device, backend, tuple_args, in_avals, out_avals, has_unordered_effects, ordered_effects, kept_var_idx, keepalive, host_callbacks)
#    1192     with log_elapsed_time(f"Finished XLA compilation of {name} "
#    1193                           "in {elapsed_time} sec"):
# -> 1194       compiled = compile_or_get_cached(backend, xla_computation, options,
#    1195                                        host_callbacks)
#    1196     buffer_counts = get_buffer_counts(out_avals, ordered_effects,
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in compile_or_get_cached(backend, computation, compile_options, host_callbacks)
#    1075       return compiled
#    1076
# -> 1077   return backend_compile(backend, serialized_computation, compile_options,
#    1078                          host_callbacks)
#    1079
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     312   def wrapper(*args, **kwargs):
#     313     with TraceAnnotation(name, **decorator_kwargs):
# --> 314       return func(*args, **kwargs)
#     315     return wrapper
#     316   return wrapper
#
# /Applications/anaconda3/lib/python3.9/site-packages/jax/_src/dispatch.py in backend_compile(backend, built_c, options, host_callbacks)
#    1010   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#    1011   # to take in `host_callbacks`
# -> 1012   return backend.compile(built_c, compile_options=options)
#    1013
#    1014 # TODO(phawkins): update users.
#
# KeyboardInterrupt:
# [2023-02-21 18:06:21 +0100] [67691] [CRITICAL] WORKER TIMEOUT (pid:67692)
# [2023-02-21 18:06:21 +0100] [67691] [CRITICAL] WORKER TIMEOUT (pid:67693)
# [2023-02-21 18:06:21 +0100] [67691] [CRITICAL] WORKER TIMEOUT (pid:67694)
# [2023-02-21 18:06:21 +0100] [67691] [CRITICAL] WORKER TIMEOUT (pid:67695)
# [2023-02-21 18:06:21 +0100] [67693] [INFO] Worker exiting (pid: 67693)
# [2023-02-21 18:06:21 +0100] [67692] [INFO] Worker exiting (pid: 67692)
# [2023-02-21 18:06:21 +0100] [67695] [INFO] Worker exiting (pid: 67695)
# [2023-02-21 18:06:21 +0100] [67694] [INFO] Worker exiting (pid: 67694)
# [2023-02-21 18:06:22 +0100] [67691] [WARNING] Worker with pid 67694 was terminated due to signal 9
packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/server/handlers.py", line 459, in wrapper
#     return func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/server/handlers.py", line 529, in wrapper
#     return func(*args, **kwargs)
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/server/handlers.py", line 903, in _search_runs
#     run_entities = _get_tracking_store().search_runs(
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/abstract_store.py", line 297, in search_runs
#     runs, token = self._search_runs(
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py", line 888, in _search_runs
#     run_infos = self._list_run_infos(experiment_id, run_view_type)
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py", line 839, in _list_run_infos
#     self._check_root_dir()
#   File "/Applications/anaconda3/lib/python3.9/site-packages/mlflow/store/tracking/file_store.py", line 173, in _check_root_dir
#     raise Exception("'%s' does not exist." % self.root_directory)
# Exception: '../../mlrun' does not exist.

# %% [markdown]
# ## Open MLflow UI

# %%
# Run MLFlow server and localtunnel
print()

# get_ipython().system_raw("mlflow server -h 0.0.0.0 -p 8010 --backend-store-uri $PWD/experiment_storing/ &")
get_ipython().system_raw("mlflow server -h 0.0.0.0 -p 8013 --backend-store-uri '../../../mlrun' &")
# !npx localtunnel --port 8013
# Out:
# zsh:1: command not found: npx
# [2023-02-21 14:59:10 +0100] [67691] [INFO] Starting gunicorn 20.1.0
# [2023-02-21 14:59:10 +0100] [67691] [INFO] Listening at: http://0.0.0.0:8013 (67691)
# [2023-02-21 14:59:10 +0100] [67691] [INFO] Using worker: sync
# [2023-02-21 14:59:10 +0100] [67692] [INFO] Booting worker with pid: 67692
# [2023-02-21 14:59:10 +0100] [67693] [INFO] Booting worker with pid: 67693
# [2023-02-21 14:59:10 +0100] [67694] [INFO] Booting worker with pid: 67694
# [2023-02-21 14:59:10 +0100] [67695] [INFO] Booting worker with pid: 67695

# %% [markdown]
# You can open this by typing http://localhost:8013 into your browser

# %%
# Run MLFlow server and localtunnel
print()

# get_ipython().system_raw("mlflow server -h 0.0.0.0 -p 8010 --backend-store-uri $PWD/experiment_storing/ &")
get_ipython().system_raw("mlflow server -h 0.0.0.0 -p 8013 --backend-store-uri '../../../../mlrun_save' &")
# !npx localtunnel --port 8013
# Out:
# zsh:1: command not found: npx
# [2023-04-12 13:23:51 +0200] [22634] [INFO] Starting gunicorn 20.1.0
# [2023-04-12 13:23:51 +0200] [22634] [INFO] Listening at: http://0.0.0.0:8013 (22634)
# [2023-04-12 13:23:51 +0200] [22634] [INFO] Using worker: sync
# [2023-04-12 13:23:51 +0200] [22635] [INFO] Booting worker with pid: 22635
# [2023-04-12 13:23:51 +0200] [22636] [INFO] Booting worker with pid: 22636
# [2023-04-12 13:23:51 +0200] [22637] [INFO] Booting worker with pid: 22637
# [2023-04-12 13:23:51 +0200] [22638] [INFO] Booting worker with pid: 22638

# %%
# Run MLFlow server and localtunnel
print()

# get_ipython().system_raw("mlflow server -h 0.0.0.0 -p 8010 --backend-store-uri $PWD/experiment_storing/ &")
get_ipython().system_raw("mlflow server -h 0.0.0.0 -p 8014 --backend-store-uri '/Users/p403830/Downloads/aws_mlrun' &")
# !npx localtunnel --port 8014
# Out:
# zsh:1: command not found: npx
# [2023-06-06 10:43:40 +0200] [26430] [INFO] Starting gunicorn 20.1.0
# [2023-06-06 10:43:40 +0200] [26430] [INFO] Listening at: http://0.0.0.0:8014 (26430)
# [2023-06-06 10:43:40 +0200] [26430] [INFO] Using worker: sync
# [2023-06-06 10:43:40 +0200] [26432] [INFO] Booting worker with pid: 26432
# [2023-06-06 10:43:40 +0200] [26435] [INFO] Booting worker with pid: 26435
# [2023-06-06 10:43:40 +0200] [26436] [INFO] Booting worker with pid: 26436
# [2023-06-06 10:43:40 +0200] [26437] [INFO] Booting worker with pid: 26437
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# [2023-06-06 13:10:49 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:26432)
# [2023-06-06 13:10:49 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:26435)
# [2023-06-06 13:10:49 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:26436)
# [2023-06-06 13:10:49 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:26437)
# [2023-06-06 13:10:49 +0200] [26432] [INFO] Worker exiting (pid: 26432)
# [2023-06-06 13:10:49 +0200] [26435] [INFO] Worker exiting (pid: 26435)
# [2023-06-06 13:10:49 +0200] [26436] [INFO] Worker exiting (pid: 26436)
# [2023-06-06 13:10:49 +0200] [26437] [INFO] Worker exiting (pid: 26437)
# [2023-06-06 13:10:50 +0200] [26430] [WARNING] Worker with pid 26437 was terminated due to signal 9
# [2023-06-06 13:10:50 +0200] [26430] [WARNING] Worker with pid 26435 was terminated due to signal 9
# [2023-06-06 13:10:50 +0200] [26430] [WARNING] Worker with pid 26432 was terminated due to signal 9
# [2023-06-06 13:10:50 +0200] [26430] [WARNING] Worker with pid 26436 was terminated due to signal 9
# [2023-06-06 13:10:50 +0200] [32597] [INFO] Booting worker with pid: 32597
# [2023-06-06 13:10:50 +0200] [32598] [INFO] Booting worker with pid: 32598
# [2023-06-06 13:10:50 +0200] [32600] [INFO] Booting worker with pid: 32600
# [2023-06-06 13:10:50 +0200] [32601] [INFO] Booting worker with pid: 32601
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '603983687658095993'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/603983687658095993/meta.yaml' does not exist.
# WARNING:root:Malformed experiment '634047769586963630'. Detailed error Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 290, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 383, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1096, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1089, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML3/ml_based_sat_solver/.venv/lib/python3.11/site-packages/mlflow/utils/file_utils.py", line 215, in read_yaml
#     raise MissingConfigException("Yaml file '%s' does not exist." % file_path)
# mlflow.exceptions.MissingConfigException: Yaml file '/Users/p403830/Downloads/aws_mlrun/634047769586963630/meta.yaml' does not exist.
# [2023-06-06 15:59:19 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:32597)
# [2023-06-06 15:59:19 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:32598)
# [2023-06-06 15:59:19 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid:32600)
# [2023-06-06 15:59:19 +0200] [26430] [CRITICAL] WORKER TIMEOUT (pid