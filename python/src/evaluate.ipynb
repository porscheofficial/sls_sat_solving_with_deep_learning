# %%
from evaluate_with_given_params import load_model_and_test_moser_traj

data_path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/GIT_SAT_ML/data/BroadcastTestSet_subset"
model_path = ["/Users/p403830/Downloads/params_save/VCG_broadcast20230506-122246_final.npy"]
colors = ["cyan"]
model_names = ["VCG - DM LLL"]
N_STEPS_MOSER = 50000
N_RUNS_MOSER = 2
path_trajs = "/Users/p403830/Desktop/" + "model_broadcast_test_subset_test_BroadcastTestSet_subset.npy"
load_model_and_test_moser_traj(
    data_path, model_path, model_names, N_STEPS_MOSER, N_RUNS_MOSER, colors, path_trajs = False
)
# Out:
# VCG - DM LLL
# problem  1 of  17
# problem  2 of  17
# problem  3 of  17
# problem  4 of  17
# problem  5 of  17
# problem  6 of  17
# problem  7 of  17
# problem  8 of  17
# problem  9 of  17
# problem  10 of  17
# problem  11 of  17
# problem  12 of  17
# problem  13 of  17
# problem  14 of  17
# problem  15 of  17
# problem  16 of  17
# problem  17 of  17

# %%
from evaluate_with_given_params import load_model_and_test_moser_traj

data_path = "/Users/p403830/Library/CloudStorage/OneDrive-PorscheDigitalGmbH/programming/generateSAT/samples_n300_subset"
model_path = ["../../experiments/params_save/random_3SAT20230530-134743.npy"]
colors = ["cyan"]
model_names = ["model"]
N_STEPS_MOSER = 50000
N_RUNS_MOSER = 2
path_trajs = False #"/Users/p403830/Desktop/" + "model_broadcast_test_subset_test_BroadcastTestSet_subset.npy"
load_model_and_test_moser_traj(
    data_path, model_path, model_names, N_STEPS_MOSER, N_RUNS_MOSER, colors, path_trajs = False
)
# Out:
# model
# problem  1 of  3
# problem  2 of  3
# problem  3 of  3
