# %%
import moser_rust
import numpy as np

# %%
from pysat.formula import CNF

# %%
path = "../../Data/blocksworld/anomaly.cnf"

cnf = CNF()
cnf.from_file(path)

nsteps = 1000
nruns = 10

# %%
# weights = np.full((cnf.nv,), 0.5)
weights = np.random.rand(cnf.nv,)

# %%
found_solution, last_assignment, final_energies = moser_rust.run_moser_python(path, weights, nsteps, nruns)
# Out:
# Loading problem with 48 variables and 261 clauses
# Round 1 ending with 191 violated clauses
# Round 2 ending with 214 violated clauses
# Round 3 ending with 200 violated clauses
# Round 4 ending with 192 violated clauses
# Round 5 ending with 211 violated clauses
# Round 6 ending with 211 violated clauses
# Round 7 ending with 218 violated clauses
# Round 8 ending with 189 violated clauses
# Round 9 ending with 202 violated clauses
# Round 10 ending with 191 violated clauses

# %%
results = %timeit -o moser_rust.run_moser_python(path, weights, nsteps, nruns)
# Out:
# Loading problem with 48 variables and 261 clauses
# Round 1 ending with 199 violated clauses
# Round 2 ending with 198 violated clauses
# Round 3 ending with 197 violated clauses
# Round 4 ending with 195 violated clauses
# Round 5 ending with 209 violated clauses
# Round 6 ending with 198 violated clauses
# Round 7 ending with 204 violated clauses
# Round 8 ending with 206 violated clauses
# Round 9 ending with 194 violated clauses
# Round 10 ending with 180 violated clauses
# Loading problem with 48 variables and 261 clauses
# Round 1 ending with 204 violated clauses
# Round 2 ending with 202 violated clauses
# Round 3 ending with 215 violated clauses
# Round 4 ending with 206 violated clauses
# Round 5 ending with 201 violated clauses
# Round 6 ending with 207 violated clauses
# Round 7 ending with 201 violated clauses
# Round 8 ending with 216 violated clauses
# Round 9 ending with 195 violated clauses
# Round 10 ending with 208 violated clauses
# ...

# %%
results
# Out:
# <TimeitResult : 19.8 ms ± 9.92 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)>
